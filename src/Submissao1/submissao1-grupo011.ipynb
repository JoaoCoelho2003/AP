# %% [markdown]
# # AI Text Detection Model Evaluation
#
# This notebook evaluates multiple models on a test dataset and compares their performance.

# %%
import numpy as np
import pandas as pd
import pickle
import os
import sys
import time
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

sys.path.append('../')
np.random.seed(2025)

from models.numpyModels.dnn.neuralnet import NeuralNetwork
from models.numpyModels.rnn.rnn import RNN
from models.numpyModels.rnn.optimizers import AdamOptimizer

os.makedirs('results', exist_ok=True)

# %% [markdown]
# ## Load Dataset

# %%
file_path = "../datasets/dataset2_inputs.csv"

with open(file_path, 'r') as file:
    csv_content = file.read()

rows = []
lines = csv_content.split('\n')
for line in lines:
    if not line.strip():
        continue
        
    parts = line.split(';', 1)
    if len(parts) >= 2:
        id_val = parts[0].strip()
        text_val = parts[1].strip()
        rows.append({'ID': id_val, 'Text': text_val})

df = pd.DataFrame(rows[1:])
print(f"Successfully read {len(df)} rows")
print(df)
# Out:
# Successfully read 100 rows
#         ID                                               Text
# 0     D2-1  The Solar System faces a dramatic future over ...
# 1     D2-2  Spermidine is an aliphatic polyamine. Spermidi...
# 2     D2-3  The feasibility of extraterrestrial life is a ...
# 3     D2-4  Many cross sectional and prospective studies h...
# 4     D2-5  There were observations of spectral lines. Tha...
# ..     ...                                                ...
# 95   D2-96  Though a part of the continent of North Americ...
# 96   D2-97  There has been a steady increase in the number...
# 97   D2-98  Plasticizers like phthalates were thought to b...
# 98   D2-99  The main causes of lung cancer are multifacete...
# 99  D2-100  It is an approximation useful in chemistry, bu...
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Load Models

# %%
class DatasetWrapper:
    def __init__(self, X, y=None):
        self.X = X
        self.y = y

def load_model(model_type):
    if model_type == "dnn":
        model = NeuralNetwork()
        model.load("../trained_models/numpy/dnn_weights.npz")
        
        with open("../preprocessed/vectorizer.pkl", "rb") as f:
            vectorizer = pickle.load(f)
        
        return model, vectorizer, None, None
    
    elif model_type == "rnn":
        embedding_matrix = np.load("../preprocessed/embedding_matrix.npy")
        
        model = RNN(n_units=64, embedding_matrix=embedding_matrix)
        model.initialize(AdamOptimizer())
        model.load("../trained_models/numpy/rnn_weights.npz")
        
        with open("../preprocessed/word_to_idx.pkl", "rb") as f:
            word_to_idx = pickle.load(f)
        
        return model, None, word_to_idx, embedding_matrix

models = {}
vectorizers = {}
word_to_idxs = {}
embedding_matrices = {}

for model_type in ["dnn", "rnn"]:
    try:
        model, vectorizer, word_to_idx, embedding_matrix = load_model(model_type)
        models[model_type] = model
        vectorizers[model_type] = vectorizer
        word_to_idxs[model_type] = word_to_idx
        embedding_matrices[model_type] = embedding_matrix
        print(f"Successfully loaded {model_type} model")
    except Exception as e:
        print(f"Error loading {model_type} model: {str(e)}")
# Out:
# Successfully loaded dnn model
# Successfully loaded rnn model

# %% [markdown]
# ## Define Prediction Function

# %%
nltk.download("punkt", quiet=True)
nltk.download("stopwords", quiet=True)

def clean_text(text):
    text = text.lower()
    text = re.sub(f"[{string.punctuation}]", "", text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words("english"))
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

def predict_text(model, vectorizer, word_to_idx, embedding_matrix, text, model_type):
    tokens = clean_text(text)
    
    if model_type == "rnn":
        max_seq_length = 100
        sequence = np.zeros((1, max_seq_length), dtype=int)
        
        for j, word in enumerate(tokens[:max_seq_length]):
            if word in word_to_idx:
                sequence[0, j] = word_to_idx[word]
        
        predictions = model.forward_propagation(sequence)
        probability = predictions[0, -1, 0]
    
    else:
        joined_text = " ".join(tokens)
        X_new = vectorizer.transform([joined_text]).toarray()
        
        class DatasetWrapper:
            def __init__(self, X):
                self.X = X
        probability = model.predict(DatasetWrapper(X_new))[0][0]

    prediction = "AI" if probability >= 0.5 else "Human"
    return prediction, probability

# %% [markdown]
# ## Make Predictions

# %%
results = {}
for model_type in models.keys():
    results[model_type] = pd.DataFrame(columns=['ID', 'Label'])

total_rows = len(df)
print(f"Making predictions on {total_rows} samples...")

start_time = time.time()
update_interval = max(1, total_rows // 20)

for index, row in df.iterrows():
    if index % update_interval == 0 or index == total_rows - 1:
        elapsed = time.time() - start_time
        progress = (index + 1) / total_rows * 100
        print(f"Progress: {progress:.1f}% ({index+1}/{total_rows}) - Elapsed: {elapsed:.1f}s")
    
    id_val = row['ID']
    print(row)
    text = row['Text']
    
    for model_type in models.keys():
        try:
            model = models[model_type]
            vectorizer = vectorizers[model_type]
            word_to_idx = word_to_idxs[model_type]
            embedding_matrix = embedding_matrices[model_type]
            
            prediction, _ = predict_text(model, vectorizer, word_to_idx, embedding_matrix, text, model_type)
            new_row = pd.DataFrame({'ID': [id_val], 'Label': [prediction]})
            results[model_type] = pd.concat([results[model_type], new_row], ignore_index=True)
        except Exception as e:
            print(f"Error with {model_type} model on text {id_val}: {str(e)}")
            new_row = pd.DataFrame({'ID': [id_val], 'Label': ['Error']})
            results[model_type] = pd.concat([results[model_type], new_row], ignore_index=True)

print(f"Predictions completed in {time.time() - start_time:.1f} seconds")
# Out:
# Making predictions on 100 samples...
# Progress: 1.0% (1/100) - Elapsed: 0.0s
# ID                                                   D2-1
# Text    The Solar System faces a dramatic future over ...
# Name: 0, dtype: object
# ID                                                   D2-2
# Text    Spermidine is an aliphatic polyamine. Spermidi...
# Name: 1, dtype: object
# ID                                                   D2-3
# Text    The feasibility of extraterrestrial life is a ...
# Name: 2, dtype: object
# ID                                                   D2-4
# Text    Many cross sectional and prospective studies h...
# Name: 3, dtype: object
# ID                                                   D2-5
# Text    There were observations of spectral lines. Tha...
# Name: 4, dtype: object
# Progress: 6.0% (6/100) - Elapsed: 0.0s
# ID                                                   D2-6
# Text    The active quest for extra-solar planets has o...
# Name: 5, dtype: object
# ID                                                   D2-7
# Text    Spermidine synthases are essential enzymes tha...
# Name: 6, dtype: object
# ID                                                   D2-8
# Text    Fossils appear to have directly contributed to...
# Name: 7, dtype: object
# ID                                                   D2-9
# Text    "There are two types of diabetes: type 1, wher...
# Name: 8, dtype: object
# ID                                                  D2-10
# Text    The origin of angiosperms (flowering plants) r...
# Name: 9, dtype: object
# Progress: 11.0% (11/100) - Elapsed: 0.1s
# ID                                                  D2-11
# Text    These nutrients are needed to keep bones, teet...
# Name: 10, dtype: object
# ID                                                  D2-12
# Text    Vitamin D is essential for maintaining healthy...
# Name: 11, dtype: object
# ID                                                  D2-13
# Text    Within 50 million years, the pressure and dens...
# Name: 12, dtype: object
# ID                                                  D2-14
# Text    Molecular data on relationships within angiosp...
# Name: 13, dtype: object
# ID                                                  D2-15
# Text    There are an estimated 2 trillion galaxies in ...
# Name: 14, dtype: object
# Progress: 16.0% (16/100) - Elapsed: 0.1s
# ID                                                  D2-16
# Text    Type 2 diabetes rates have risen dramatically ...
# Name: 15, dtype: object
# ID                                                  D2-17
# Text    Quarks and gluons are both fundamental particl...
# Name: 16, dtype: object
# ID                                                  D2-18
# Text    Insects as food or edible insects are insect s...
# Name: 17, dtype: object
# ID                                                  D2-19
# Text    Schrödinger's cat is a famous thought experime...
# Name: 18, dtype: object
# ID                                                  D2-20
# Text    For a fossil to exist it needs to survive a lo...
# Name: 19, dtype: object
# Progress: 21.0% (21/100) - Elapsed: 0.1s
# ID                                                  D2-21
# Text    The probability of extraterrestrial life exist...
# Name: 20, dtype: object
# ID                                                  D2-22
# Text    Insects can be used for food production and ar...
# Name: 21, dtype: object
# ID                                                  D2-23
# Text    Diabetes type 1 and type 2 are both chronic co...
# Name: 22, dtype: object
# ID                                                  D2-24
# Text    Entomophagy—the practice of consuming insects ...
# Name: 23, dtype: object
# ID                                                  D2-25
# Text    Quarks and gluons are fundamental particles in...
# Name: 24, dtype: object
# Progress: 26.0% (26/100) - Elapsed: 0.1s
# ID                                                  D2-26
# Text    The global increase in demand for meat and the...
# Name: 25, dtype: object
# ID                                                  D2-27
# Text    In 1802, Lamarck published Hydrogéologie, and ...
# Name: 26, dtype: object
# ID                                                  D2-28
# Text    Fossils have played a significant role in shap...
# Name: 27, dtype: object
# ID                                                  D2-29
# Text    Synthetic biology emerged as a specialized bra...
# Name: 28, dtype: object
# ID                                                  D2-30
# Text    More than 1,900 species of edible insects are ...
# Name: 29, dtype: object
# Progress: 31.0% (31/100) - Elapsed: 0.1s
# ID                                                  D2-31
# Text    Vitamin D plays a crucial role in human health...
# Name: 30, dtype: object
# ID                                                  D2-32
# Text    Synthetic biology is bringing together enginee...
# Name: 31, dtype: object
# ID                                                  D2-33
# Text    Computational systems biology is an emerging f...
# Name: 32, dtype: object
# ID                                                  D2-34
# Text    The main causes of lung cancer are primarily l...
# Name: 33, dtype: object
# ID                                                  D2-35
# Text    Einstein and Schrödinger exchanged significant...
# Name: 34, dtype: object
# Progress: 36.0% (36/100) - Elapsed: 0.1s
# ID                                                  D2-36
# Text    Per- and polyfluoroalkyl substances (PFAS) are...
# Name: 35, dtype: object
# ID                                                  D2-37
# Text    Obesity and type 2 diabetes have a close relat...
# Name: 36, dtype: object
# ID                                                  D2-38
# Text    The variation in PFAS regulatory values across...
# Name: 37, dtype: object
# ID                                                  D2-39
# Text    Rates of type 2 diabetes have increased marked...
# Name: 38, dtype: object
# ID                                                  D2-40
# Text    An unexpected emergent property of a complex s...
# Name: 39, dtype: object
# Progress: 41.0% (41/100) - Elapsed: 0.2s
# ID                                                  D2-41
# Text    Quarks are fundamental particles that make up ...
# Name: 40, dtype: object
# ID                                                  D2-42
# Text    In order to determine how much Vitamin D suppl...
# Name: 41, dtype: object
# ID                                                  D2-43
# Text    Early lung cancer often has no symptoms and ca...
# Name: 42, dtype: object
# ID                                                  D2-44
# Text    To further illustrate, Schrödinger described h...
# Name: 43, dtype: object
# ID                                                  D2-45
# Text    Educational robotics teaches the design, analy...
# Name: 44, dtype: object
# Progress: 46.0% (46/100) - Elapsed: 0.2s
# ID                                                  D2-46
# Text    Obesity is recognized as a major risk factor f...
# Name: 45, dtype: object
# ID                                                  D2-47
# Text    Systems Biology is not one thing, and is quite...
# Name: 46, dtype: object
# ID                                                  D2-48
# Text    Educational robotics represents an innovative ...
# Name: 47, dtype: object
# ID                                                  D2-49
# Text    According to Poe, the initial state of matter ...
# Name: 48, dtype: object
# ID                                                  D2-50
# Text    The expanding Sun is expected to vaporize Merc...
# Name: 49, dtype: object
# Progress: 51.0% (51/100) - Elapsed: 0.2s
# ID                                                  D2-51
# Text    The Big Bang theory is the predominant scienti...
# Name: 50, dtype: object
# ID                                                  D2-52
# Text    Mainstream physicists treat “quarks” and “gluo...
# Name: 51, dtype: object
# ID                                                  D2-53
# Text    Lavoisier's Law, formally known as the Law of ...
# Name: 52, dtype: object
# ID                                                  D2-54
# Text    Using the Schwinger-Dyson equations the behavi...
# Name: 53, dtype: object
# ID                                                  D2-55
# Text    In physics and chemistry, the law of conservat...
# Name: 54, dtype: object
# Progress: 56.0% (56/100) - Elapsed: 0.2s
# ID                                                  D2-56
# Text    Metabolic engineering is a specialized field t...
# Name: 55, dtype: object
# ID                                                  D2-57
# Text    In modern terms Schrodinger's hypothetical cat...
# Name: 56, dtype: object
# ID                                                  D2-58
# Text    The Big Bang theory is the prevailing cosmolog...
# Name: 57, dtype: object
# ID                                                  D2-59
# Text    Synthetic biology, which aims to design or ass...
# Name: 58, dtype: object
# ID                                                  D2-60
# Text    The dangers of PFAS, or per- and polyfluoroalk...
# Name: 59, dtype: object
# Progress: 61.0% (61/100) - Elapsed: 0.2s
# ID                                                  D2-61
# Text    Aminopropyltransferases transfer aminopropyl g...
# Name: 60, dtype: object
# ID                                                  D2-62
# Text    Educational robotics offers a wealth of advant...
# Name: 61, dtype: object
# ID                                                  D2-63
# Text    The use of insects for food represents a promi...
# Name: 62, dtype: object
# ID                                                  D2-64
# Text    Spermidine synthase (SpdS) is an enzyme respon...
# Name: 63, dtype: object
# ID                                                  D2-65
# Text    Understanding Greenland ice sheet (GrIS) hydro...
# Name: 64, dtype: object
# Progress: 66.0% (66/100) - Elapsed: 0.3s
# ID                                                  D2-66
# Text    Computational systems biology is crucial for u...
# Name: 65, dtype: object
# ID                                                  D2-67
# Text    The Lavoisier Law, also known as the Law of Co...
# Name: 66, dtype: object
# ID                                                  D2-68
# Text    The ultimate goal of metabolic engineering is ...
# Name: 67, dtype: object
# ID                                                  D2-69
# Text    Lavoisier was born in 1743 into a wealthy fami...
# Name: 68, dtype: object
# ID                                                  D2-70
# Text    Lavoisier’s law, also known as the Law of Cons...
# Name: 69, dtype: object
# Progress: 71.0% (71/100) - Elapsed: 0.3s
# ID                                                  D2-71
# Text    Metabolic engineering is the field of biotechn...
# Name: 70, dtype: object
# ID                                                  D2-72
# Text    Synthetic biology is an interdisciplinary fiel...
# Name: 71, dtype: object
# ID                                                  D2-73
# Text    Lamarck's ""Hydrogéologie"" (1802) represents ...
# Name: 72, dtype: object
# ID                                                  D2-74
# Text    Greenland is the world’s largest island, locat...
# Name: 73, dtype: object
# ID                                                  D2-75
# Text    The Big Bang theory is an effort to explain wh...
# Name: 74, dtype: object
# Progress: 76.0% (76/100) - Elapsed: 0.3s
# ID                                                  D2-76
# Text    Phthalates or phthalate esters, are esters of ...
# Name: 75, dtype: object
# ID                                                  D2-77
# Text    The possibility of extraterrestrial life is ro...
# Name: 76, dtype: object
# ID                                                  D2-78
# Text    Since the mid-20th century, active research ha...
# Name: 77, dtype: object
# ID                                                  D2-79
# Text    Greenland is as old as the rest of the earth. ...
# Name: 78, dtype: object
# ID                                                  D2-80
# Text    A PET (Positron Emission Tomography) scan is a...
# Name: 79, dtype: object
# Progress: 81.0% (81/100) - Elapsed: 0.3s
# ID                                                  D2-81
# Text    Educational robotics has a wide range of appli...
# Name: 80, dtype: object
# ID                                                  D2-82
# Text    A PET scan (Positron Emission Tomography) is a...
# Name: 81, dtype: object
# ID                                                  D2-83
# Text    Metabolic engineering is a multidisciplinary f...
# Name: 82, dtype: object
# ID                                                  D2-84
# Text    Fossils are the preserved remains or traces of...
# Name: 83, dtype: object
# ID                                                  D2-85
# Text    A PET scan, or Positron Emission Tomography, i...
# Name: 84, dtype: object
# Progress: 86.0% (86/100) - Elapsed: 0.3s
# ID                                                  D2-86
# Text    Robotic education is nothing but the Hybrid Ed...
# Name: 85, dtype: object
# ID                                                  D2-87
# Text    Join any group of distance educators today and...
# Name: 86, dtype: object
# ID                                                  D2-88
# Text    Jean-Baptiste Lamarck’s Hydrogéologie (1802) p...
# Name: 87, dtype: object
# ID                                                  D2-89
# Text    Greenland, the world's largest island that isn...
# Name: 88, dtype: object
# ID                                                  D2-90
# Text    The principle of positron emission tomography ...
# Name: 89, dtype: object
# Progress: 91.0% (91/100) - Elapsed: 0.4s
# ID                                                  D2-91
# Text    The Big Bang theory is the leading explanation...
# Name: 90, dtype: object
# ID                                                  D2-92
# Text    With the emergence of positron emission tomogr...
# Name: 91, dtype: object
# ID                                                  D2-93
# Text    Metabolic engineering is not another form of c...
# Name: 92, dtype: object
# ID                                                  D2-94
# Text    Synthetic biology is an interdisciplinary fiel...
# Name: 93, dtype: object
# ID                                                  D2-95
# Text    Positron emission tomography (PET) is a functi...
# Name: 94, dtype: object
# Progress: 96.0% (96/100) - Elapsed: 0.4s
# ID                                                  D2-96
# Text    Though a part of the continent of North Americ...
# Name: 95, dtype: object
# ID                                                  D2-97
# Text    There has been a steady increase in the number...
# Name: 96, dtype: object
# ID                                                  D2-98
# Text    Plasticizers like phthalates were thought to b...
# Name: 97, dtype: object
# ID                                                  D2-99
# Text    The main causes of lung cancer are multifacete...
# Name: 98, dtype: object
# Progress: 100.0% (100/100) - Elapsed: 0.4s
# ID                                                 D2-100
# Text    It is an approximation useful in chemistry, bu...
# Name: 99, dtype: object
# Predictions completed in 0.4 seconds

# %% [markdown]
# ## Save Results to CSV

# %%
count = 1
for model_type, df in results.items():
    output_path = f"results/submissao1-grupo011-s{count}.csv"
    df.to_csv(output_path, sep='\t', index=False)
    print(f"Saved predictions for {model_type} model to {output_path}")
    count += 1
# Out:
# Saved predictions for dnn model to results/submissao1-grupo011-s1.csv
# Saved predictions for rnn model to results/submissao1-grupo011-s2.csv
